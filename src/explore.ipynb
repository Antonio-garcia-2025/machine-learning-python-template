# %% [markdown]
# # Explore here

# %%
from data.raw.info import load_data
import pandas as pd

df = load_data()
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from data.raw.info import load_data
#       2 import pandas as pd
#       4 df = load_data()
#
# ModuleNotFoundError: No module named 'data'

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.isna().sum().sort_values(ascending = False)
#
# NameError: name 'df' is not defined

# %%
df = df[df["price"] > 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = df[df["price"] > 0]
#
# NameError: name 'df' is not defined

# %%
no_aportan = ["id","name","host_name","last_review"]
df = df.drop(
    columns=[c for c in no_aportan if c in df.columns]
)
df.columns
# Out:
# Index(['host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

plt.hist(df["price"], bins = 50)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df = df[(df["price"] > 0) & (df["price"] < 500)]

# %%
df["room_type"] = df["room_type"].astype("category")
df["neighbourhood_group"] = df["neighbourhood_group"].astype("category")

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only=True))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 import seaborn as sns
# ----> 2 sns.heatmap(df.corr(numeric_only=True))
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt 
plt.hist(df["price"], bins=50)
plt.xlabel("price")
plt.ylabel("frecuencia")
plt.title("distribucion de precio")
plt.show()
